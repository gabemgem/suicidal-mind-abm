# %%
import numpy as np
from suicidal_mind import SuicidalMind
from event import Event

# %%
rng = np.random.default_rng(123)

smind = SuicidalMind("smind", rng=rng, dt=0.1 )

# %%
smind.step_to(10)

# %%
df = smind.df()
df[["CAPABILITY","DESIRE","RISK"]].plot()
# Out:
# <Axes: >
